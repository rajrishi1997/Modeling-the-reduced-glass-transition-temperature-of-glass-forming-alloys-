# %% [markdown]
# # REGRESSION ANALYSIS

# %% [markdown]
# Name-Rajrishi Sarkar
# Roll-203110061

# %% [markdown]
# ## Data description

# %% [markdown]
# **Metallic Glass Descriptors:**
#
# 	Relevant papers:
# 		There is no paper published on this data set at the present time.  The data was assembled
# 		primarily by Vanessa Nilsen under the guidance of Prof. Dane Morgan at UW Madison
# 		 (ddmorgan@wisc.edu).
# 		A previous study of reduced glass transition temperature as a GFA descriptor can be found in reference [5]:
# 		https://www.sciencedirect.com/science/article/pii/S0022309300000648
#
# 	X features:
# 		The metallic glass dataset gives two columns with information about the material
# 		Composition. The first is the overall composition, and the second is the highest
# 		Composition element. The columns from four to the end are the MAGPIE features that
# 		have been generated from the material composition column and give values such as
# 		properties averaged over the material composition as well as features that are only for
# 		the majority element in each alloy [3]. The majority element features are labelled as
# 		"site1".
#
# 	Y property:
# 		The reduced glass transition temperature (Trg) has historically been used as a rough
# 		predictor for Glass Forming Ability (GFA). By making a model to predict Trg for an
# 		arbitrary alloy, it could be possible to use these values to estimate GFA directly, or as
# 		input for another model to then predict GFA.

# %% [markdown]
# ## Importing the dataset

# %%
data<-read.csv("C:\\Users\\ADMIN\\Desktop\\data for data analysis\\stats project\\features.csv")
df<-as.data.frame(data)
#viewing the datset
head(df)
# Out:
#   Material.compositions main_element Trg   Density_composition_average
# 1 Ag10Cu35Zr55          Zr           0.534  0.57906932
# 2 Ag10Cu50Zr40          Cu           0.608  0.74840145
# 3 Ag10Cu55Zr35          Cu           0.609  0.80484550
# 4 Ag20Cu40Zr40          Cu           0.577  0.82197318
# 5 Ag35Ca65              Ca           0.515 -0.86099185
# 6 Al13.3Co26.7Zr60      Zr           0.573  0.05888908
#   IsBoron_composition_average IsDBlock_composition_average
# 1 -0.5856000                   1.0298821
# 2 -0.5856000                   1.0298821
# 3 -0.5856000                   1.0298821
# 4 -0.5856000                   1.0298821
# 5 -0.5856000                  -0.9989612
# 6  0.4642294                   0.6147495
#   IsTransitionMetal_composition_average NdValence_composition_average
# 1  1.0298821                             0.5895359
# 2  1.0298821                             1.1762502
# 3  1.0298821                             1.3718216
# ...

# %%
#visualizing the data dimensions
dim(df)
# Out:
# [1] 585  23

# %% [markdown]
# The dataset has 23 columns one is the target feature and the remaining 22 are independent features
# out of the remaining 22 features we will not be needing the features:"Material.Compositions" & "main_element"

# %% [markdown]
# ## Regression

# %% [markdown]
# ## Simple linear regression

# %%
mod1 <- lm(Trg~Density_composition_average,data=df)
summary(mod1)
# Out:
# Call:
# lm(formula = Trg ~ Density_composition_average, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.35961 -0.01857  0.00681  0.02654  0.13726
#
# Coefficients:
#                             Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 0.577388   0.001933 298.735  < 2e-16 ***
# Density_composition_average 0.012462   0.001933   6.448 2.39e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.04675 on 583 degrees of freedom
# Multiple R-squared:  0.06656,	Adjusted R-squared:  0.06496
# F-statistic: 41.57 on 1 and 583 DF,  p-value: 2.387e-10

# %%
par(mfrow=c(2,2))
plot(mod1)
# Out:
# Plot with title ""

# %%
mod2 <- lm(Trg~IsBoron_composition_average,data=df)
summary(mod2)
# Out:
# Call:
# lm(formula = Trg ~ IsBoron_composition_average, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.36235 -0.02333  0.00509  0.03040  0.14020
#
# Coefficients:
#                             Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  0.57739    0.00192  300.77  < 2e-16 ***
# IsBoron_composition_average -0.01359    0.00192   -7.08 4.17e-12 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.04643 on 583 degrees of freedom
# Multiple R-squared:  0.07917,	Adjusted R-squared:  0.07759
# F-statistic: 50.12 on 1 and 583 DF,  p-value: 4.169e-12

# %%
par(mfrow=c(2,2))
plot(mod2)
# Out:
# Plot with title ""

# %%
(anova(mod1,mod2))
# Out:
#   Res.Df RSS      Df Sum of Sq  F  Pr(>F)
# 1 583    1.274053 NA         NA NA NA
# 2 583    1.256843  0 0.01721064 NA NA

# %%
mod3 <- lm(Trg~IsDBlock_composition_average,data=df)
summary(mod3)
par(mfrow=c(2,2))
plot(mod3)
# Out:
# Call:
# lm(formula = Trg ~ IsDBlock_composition_average, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37129 -0.01677  0.00525  0.02600  0.14493
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  0.577388   0.001882  306.87   <2e-16 ***
# IsDBlock_composition_average 0.016408   0.001882    8.72   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.04551 on 583 degrees of freedom
# Multiple R-squared:  0.1154,	Adjusted R-squared:  0.1139
# F-statistic: 76.05 on 1 and 583 DF,  p-value: < 2.2e-16
# Plot with title ""

# %%
anova(mod1,mod2,mod3)
# Out:
#   Res.Df RSS      Df Sum of Sq  F  Pr(>F)
# 1 583    1.274053 NA         NA NA NA
# 2 583    1.256843  0 0.01721064 NA NA
# 3 583    1.207406  0 0.04943663 NA NA

# %% [markdown]
# ## Multiple linear regression

# %%
mod4 <-lm(Trg~Density_composition_average+IsBoron_composition_average+IsDBlock_composition_average+IsTransitionMetal_composition_average+NdValence_composition_average+NValance_composition_average+HeatVaporization_max_value+BoilingT_difference+HeatVaporization_difference+MeltingT_difference+NdValence_difference+NsUnfilled_difference+valence_difference+Site1_Density+Site1_HeatCapacityMass+Site1_HeatFusion+Site1_IsDBlock+Site1_IsTransitionMetal+Site1_NdValence+Site1_SpecificHeatCapacity,data=df)
summary(mod4)
par(mfrow=c(2,2))
plot(mod4)
# Out:
# Call:
# lm(formula = Trg ~ Density_composition_average + IsBoron_composition_average +
#     IsDBlock_composition_average + IsTransitionMetal_composition_average +
#     NdValence_composition_average + NValance_composition_average +
#     HeatVaporization_max_value + BoilingT_difference + HeatVaporization_difference +
#     MeltingT_difference + NdValence_difference + NsUnfilled_difference +
#     valence_difference + Site1_Density + Site1_HeatCapacityMass +
#     Site1_HeatFusion + Site1_IsDBlock + Site1_IsTransitionMetal +
#     Site1_NdValence + Site1_SpecificHeatCapacity, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.33181 -0.01719  0.00424  0.02306  0.16366
#
# Coefficients: (2 not defined because of singularities)
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                            0.577388   0.001682 343.329  < 2e-16 ***
# ...

# %% [markdown]
# **OBSERVATION**:
# We have plotted for graphs. The first graph shows the fitted values against the observed resididuals. In this plot the dots should be randomly placed around the horizontal zero line, which is clearly not the case. It seems that there are three groups present. Thus per group there is difference in variance across the residuals.
#
# There is increasing variance across the residuals (heteroscedasticity), and there migth also be a non-linear relationship between the outcome and the predictor. This non-linear relationship is also reflected by the second plot (Q-Q plot), since the dots deviate from the dotted line.

# %% [markdown]
#
# by observing the summary statistics of the model 4 we see that in the coeffients section
# there are features which are not much significant and also have higher p values
# we donot need this features.
# So we will try removing these features and try again

# %% [markdown]
#
# IsDBlock_composition_average
# IsTransitionMetal_composition_average
# NdValence_composition_average
# HeatVaporization_max_value
# MeltingT_difference                         .
# NdValence_difference
# NsUnfilled_difference
# Site1_Density
# Site1_IsTransitionMetal

# %%
mod5 <-lm(Trg~Density_composition_average+IsBoron_composition_average+NValance_composition_average+BoilingT_difference+HeatVaporization_difference+valence_difference+Site1_HeatCapacityMass+Site1_HeatFusion+Site1_IsDBlock+Site1_NdValence+Site1_SpecificHeatCapacity,data=df)
summary(mod5)
par(mfrow=c(2,2))
plot(mod5)
# Out:
# Call:
# lm(formula = Trg ~ Density_composition_average + IsBoron_composition_average +
#     NValance_composition_average + BoilingT_difference + HeatVaporization_difference +
#     valence_difference + Site1_HeatCapacityMass + Site1_HeatFusion +
#     Site1_IsDBlock + Site1_NdValence + Site1_SpecificHeatCapacity,
#     data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.33216 -0.01671  0.00546  0.02541  0.14217
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   0.577388   0.001717 336.246  < 2e-16 ***
# Density_composition_average  -0.020883   0.005500  -3.797 0.000162 ***
# IsBoron_composition_average  -0.011446   0.002004  -5.712 1.80e-08 ***
# NValance_composition_average  0.013877   0.004317   3.215 0.001379 **
# BoilingT_difference           0.020863   0.005668   3.681 0.000254 ***
# HeatVaporization_difference  -0.017039   0.006527  -2.611 0.009273 **
# ...

# %% [markdown]
# **anova test of model4 and model5**`

# %%
anova(mod4,mod5)
# Out:
#   Res.Df RSS       Df Sum of Sq   F        Pr(>F)
# 1 566    0.9364531 NA          NA       NA           NA
# 2 573    0.9883985 -7 -0.05194535 4.485171 7.089873e-05
